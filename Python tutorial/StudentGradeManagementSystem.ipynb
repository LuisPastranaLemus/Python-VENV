# %%
import math

choice = ""
answer = ""
option = ""
index = 0
avrg = 0
float(avrg)
studentDataBase = [[] for i in range(5)]

# Introduction

print("*** Student Grade Management System ***")
print("\n")
choice = input("> Do you want to add a new student\'s grades? (yes or no): \n> ")
choice = choice.lower()

# Answer validation for yes or no

if choice != "yes" and choice != "no":

     print("Invalid answer, must answer with (yes or no).")
     print("Program terminated.")

elif choice == "yes":
    
    # Database filling with Student's information

    while choice == "yes":
        
        # Input Student's Name
        
        answer = input("> Input student name : \n> ")
        
        while answer.isalnum():
             
             answer = input("> Input a valid student\'s name with only alphabetic characters: \n> ")
             
             if answer.isalpha():
                  
                  break
        
        studentDataBase[0].insert(index, answer.upper())

        # Input Student's grade for MATH
        
        answer = input("> Input grades for MATH : \n> ")

        if answer.isnumeric():
             
             studentDataBase[1].insert(index, round(float(answer), 2))
             
        else: 
             
             while answer.isalnum():
                  
                  answer = input("> Input a valid student\'s grade with only numeric characters: \n> ")
              
                  if answer.isnumeric():
                       
                       studentDataBase[1].insert(index, round(float(answer), 2))
                       break

        # Input Student's grade for SCIENCE

        answer = input("> Input grades for SCINCE : \n> ")

        if answer.isnumeric():
             
             studentDataBase[2].insert(index, round(float(answer), 2))
    
        else:
             
             while answer.isalnum():
                  
                  answer = input("> Input a valid student\'s grade with only numeric characters: \n> ")
              
                  if answer.isnumeric():
                    
                    studentDataBase[2].insert(index, round(float(answer), 2))   
                    break    

        # Input Student's grade for English

        answer = input("> Input grades for English : \n> ")

        if answer.isnumeric():
             
             studentDataBase[3].insert(index, round(float(answer), 2))
             
        else:
             
             while answer.isalnum():
                  
                  answer = input("> Input a valid student\'s grade with only numeric characters: \n> ")
                  
                  if answer.isnumeric():
                       
                       studentDataBase[3].insert(index, round(float(answer), 2))
                       break    

        # Average Calculation
       
        avrg = round((studentDataBase[1][index]+studentDataBase[2][index]+studentDataBase[3][index]) / 3, 2)
        studentDataBase[4].insert(index, avrg)
    
        choice = input("> Do you want to add a new student\'s grades? (yes or no): \n> ")
        choice = choice.lower()

        if choice == "yes":
             
             index += 1
        
        elif choice != "yes" or choice != "no":
             
             print("> Invalid answer, must answer with (yes or no).")
             print("> Now will proceed to Display Students' Database Information.")
             
        else:
             break

    # Display Database with Student's Information

    index = 0
    choise = "yes"

    while choise == "yes":

         print("> Students' Database Information")
         print("> 1 - Display single Student's Information")
         print("> 2 - Display all Student's Information")
         print("> 3 - Display by avarage grade")
         print("> 4 - Display Top and Bottom Students")
         print("> 5 - Remove a student")
         print("> 0 - Exit")
         option = input("> Please choose an option: \n>")
         
         while option != "0" or option != "1" or option != "2" or option != "3" or option != "4" or option != "5":
              
              option = input("> Invalid option, please choose a valid option (1-5): \n> ")

              if option == "0" or option == "1" or option == "2" or option == "3" or option == "4" or option == "5":
                   break

         if option == "0":
              
              break
         
         elif option == "1":
              
              answer = input ("> To retrive student's information, please Input the Student's name: \n> ")
              answer.upper()

              for x in studentDataBase[0]:
                   
                   if x == answer:
                        
                        print(f"> Name: {studentDataBase[0][index]},   Grades: MATH [ {studentDataBase[1][index]} ], SCIENCE [ {studentDataBase[2][index]} ], \
                              ENGLISH [ {studentDataBase[3][index]} ],   Average: {studentDataBase[4][index]}")
                        
                        index += 1
                   
                   else:
                        
                        index += 1
         
         elif option == "2":
              
              for x in studentDataBase[0]:
                    
                    print(f"> Name: {studentDataBase[0][index]},   Grades: MATH [ {studentDataBase[1][index]} ], SCIENCE [ {studentDataBase[2][index]} ], \
                          ENGLISH [ {studentDataBase[3][index]} ],   Average: {studentDataBase[4][index]}")
                        
                    index += 1
         
         elif option == "3":
              
              print("")

         elif option == "4":
              
              print("")

         elif option == "5":
              
              print("")

         else:
              
              print("")
     
         print("")
                     


elif choice == "no":

     print("Program terminated.")

else:

     print("Invalid answer, must answer with (yes or no).")
     print("Program terminated.")
# Out:
# *** Student Grade Management System ***
#
#
# > Invalid answer, must answer with (yes or no).
# > Now will proceed to Display Students' Database Information.
# > Students' Database Information
# > 1 - Display single Student's Information
# > 2 - Display all Student's Information
# > 3 - Display by avarage grade
# > 4 - Display Top and Bottom Students
# > 5 - Remove a student
# > 0 - Exit
# > Name: LUIS PASTRANA,   Grades: MATH [ 5.0 ], SCIENCE [ 6.0 ],                           ENGLISH [ 7.0 ],   Average: 6.0
# > Name: ITZEL PRIMO,   Grades: MATH [ 6.0 ], SCIENCE [ 7.0 ],                           ENGLISH [ 8.0 ],   Average: 7.0
#
# > Students' Database Information
# > 1 - Display single Student's Information
# > 2 - Display all Student's Information
# > 3 - Display by avarage grade
# > 4 - Display Top and Bottom Students
# > 5 - Remove a student
# > 0 - Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 140
#     136 option = input("> Please choose an option: \n>")
#     138 while option != "0" or option != "1" or option != "2" or option != "3" or option != "4" or option != "5":
# --> 140      option = input("> Invalid option, please choose a valid option (1-5): \n> ")
#     142      if option == "0" or option == "1" or option == "2" or option == "3" or option == "4" or option == "5":
#     143           break
#
# File c:\Users\luisp\.virtualenvs\Python-VENV-fXy5dZEI\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File c:\Users\luisp\.virtualenvs\Python-VENV-fXy5dZEI\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
