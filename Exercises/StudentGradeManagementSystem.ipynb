# %%
import math

choice = ""
answer = ""
option = ""
index = 0
avrg = 0
amnt = 0
float(avrg)
studentDataBase = []

# Introduction

print("\n")
print("*** Student Grade Management System ***")
print("\n")
answer = input("> Input the amount of students to be registered: \n> ")

while not answer.isnumeric():
     
     answer = input("> Input only numbers: \n> ")

amnt = int(answer)

studentDataBase = [[] for _ in range(amnt)]

print("\n")
choice = input("> Do you want to add a new student\'s grades? (yes or no): \n> ")
choice = choice.lower()
print("\n")

# Answer validation for yes or no

if choice != "yes" and choice != "no":
     
     print("\n")
     print("Invalid answer, must answer with (yes or no).")
     print("Program terminated.")

elif choice == "yes":
    
    # Database filling with Student's information

    while choice == "yes":
        
        # Input Student's Name
        
        answer = input("> Input student name : \n> ")
        
        while answer.isalnum():
             
             print("\n")
             answer = input("> Input a valid student\'s name with at least one last name and only alphabetic characters: \n> ")
             print("\n")
             
             if answer.isalpha():
                  
                  break
        
        studentDataBase[index] = [answer.upper()]

        # Input Student's grade for MATH
        
        answer = input("> Input grades for MATH : \n> ")

        if answer.isnumeric():
             
             studentDataBase[index].append(round(float(answer), 2))
             
        else: 
             
             while answer.isalnum():
                  
                  print("\n")
                  answer = input("> Input a valid student\'s grade with only numeric characters: \n> ")
                  print("\n")
              
             studentDataBase[index].append(round(float(answer), 2))

        # Input Student's grade for SCIENCE

        answer = input("> Input grades for SCINCE : \n> ")

        if answer.isnumeric():
             
             studentDataBase[index].append(round(float(answer), 2))
    
        else:
             
             while answer.isalnum():
                  
                  print("\n")
                  answer = input("> Input a valid student\'s grade with only numeric characters: \n> ")
                  print("\n")
              
             studentDataBase[index].append(round(float(answer), 2))    

        # Input Student's grade for English

        answer = input("> Input grades for English : \n> ")
        print("\n")

        if answer.isnumeric():
             
             studentDataBase[index].append(round(float(answer), 2))
             
        else:
             
             while answer.isalnum():
                  
                  answer = input("> Input a valid student\'s grade with only numeric characters: \n> ")
                  print("\n")
                  
             studentDataBase[index].append(round(float(answer), 2))  

        # Average Calculation
       
        avrg = round(float((studentDataBase[index][1]) + studentDataBase[index][2]+studentDataBase[index][3]) / 3, 2)
        studentDataBase[index].append(avrg)
    
        choice = input("> Do you want to add a new student\'s grades? (yes or no): \n> ")
        choice = choice.lower()
        print("\n")

        if choice == "yes":
             
             index += 1
        
        elif choice == "no":
             
             print("> Now will proceed to Display Students' Database Information.")
             print("\n")
        
        elif choice != "yes" or choice != "no":
             
             print("> Invalid answer, must answer with (yes or no).")
             print("> Now will proceed to Display Students' Database Information.")
             print("\n")
             
        else:
             break

    # Display Database with Student's Information

    index = 0
    choise = "yes"
    avrgList = []

    while choise == "yes":

         print("> Students' Database Information")
         print("> 1 - Display single Student's Information")
         print("> 2 - Display all Student's Information")
         print("> 3 - Display by avarage grade")
         print("> 4 - Display Top and Bottom Students")
         print("> 5 - Remove a student")
         print("> 0 - Exit")
         print("> Now will proceed to Display Students' Database Information.")
         print("\n")
         option = input("> Please choose an option: \n> ")
         print("\n")
         
         while not option.isdigit() or int(option) not in range(6):
              
              option = input("> Invalid option, please choose a valid option (1-5): \n> ")
              print("\n")

              if int(option) > 6:
                   break

         if option == "0":
              
              break
         
         elif option == "1":
              
              answer = input ("> To retrive student's information, please Input the Student's name: \n> ")
              answer = answer.upper()
              print("\n")

              for x in studentDataBase:
                   
                   if x[0] == answer:
                        
                        print(f"> Name: {studentDataBase[index][0]}, Grades: MATH [ {studentDataBase[index][1]} ], SCIENCE [ {studentDataBase[index][2]} ], ENGLISH [ {studentDataBase[index][3]} ], Average: {studentDataBase[index][4]}")
                        print("\n")
                        
                        index += 1
                   
                   else:
                        
                        index += 1
              
              index = 0
         
         elif option == "2":
              
              for x in studentDataBase:
                    
                    print(f"> Name: {studentDataBase[index][0]}, Grades: MATH [ {studentDataBase[index][1]} ], SCIENCE [ {studentDataBase[index][2]} ], ENGLISH [ {studentDataBase[index][3]} ], Average: {studentDataBase[index][4]}")
                        
                    index += 1
              
              index = 0
              print("\n")
         
         elif option == "3":
              
              avrgList = studentDataBase.copy()

              avrgList.sort(key = lambda l: l[4], reverse=True)
              
              for x in studentDataBase:
                    
                    print(f"> Name: {avrgList[index][0]}, Grades: MATH [ {avrgList[index][1]} ], SCIENCE [ {avrgList[index][2]} ], ENGLISH [ {avrgList[index][3]} ], Average: {avrgList[index][4]}")
                        
                    index += 1
              
              index = 0
              print("\n")

         elif option == "4":
              
              print("")

         elif option == "5":
              
              print("")

         else:
              
              print("")
     
         print("")
# Out:
# *** Student Grade Management System ***
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# > Now will proceed to Display Students' Database Information.
#
#
# > Students' Database Information
# > 1 - Display single Student's Information
# > 2 - Display all Student's Information
# > 3 - Display by avarage grade
# > 4 - Display Top and Bottom Students
# > 5 - Remove a student
# > 0 - Exit
# > Now will proceed to Display Students' Database Information.
#
#
#
#
#
#
# > Name: ITZEL PRIMO, Grades: MATH [ 5.0 ], SCIENCE [ 6.0 ], ENGLISH [ 7.0 ], Average: 6.0
#
#
#
# > Students' Database Information
# > 1 - Display single Student's Information
# > 2 - Display all Student's Information
# > 3 - Display by avarage grade
# > 4 - Display Top and Bottom Students
# > 5 - Remove a student
# > 0 - Exit
# > Now will proceed to Display Students' Database Information.
#
#
#
#
#
#
#
# > Students' Database Information
# > 1 - Display single Student's Information
# > 2 - Display all Student's Information
# ...

# %%
# Diccionario anidado que representa productos
products = {
    'Product_A': {'price': 10, 'quantity': 2, 'discount': 0.1},
    'Product_B': {'price': 20, 'quantity': 1, 'discount': 0.05},
    'Product_C': {'price': 15, 'quantity': 5, 'discount': 0.2},
}

total_income = 0
cost = 0
mexp = ""

for p in products:
    total_income += (products[p].get("price") * (1 - products[p].get("discount"))) * products[p].get("quantity")
    if  cost < (products[p].get("price") * (1 - products[p].get("discount"))):
        cost = (products[p].get("price")) #* (1 - products[p].get("discount")))
        mexp = p

print("Ingresos totales: $", total_income)
print(f"Producto más caro: {mexp} (Precio actualizado a ${cost *(1 - 0.1)}")
# Out:
# Ingresos totales: $ 97.0
# Producto más caro: Product_B (Precio actualizado a $18.0

# %%
clients = [
    [32456, "Jack Wilson", 32, 150000, "Healthcare"],
    [34591, "Nina Brown", 45, 250000, "Telecom"],
    [37512, "Alex Smith", 39, 210000, "IT"],
    [39591, "Brian Perez", 29, 340000, "Transportation"],
    [45123, "Sarah Lee", 28, 120000, "Marketing"],
    [47635, "David Kim", 36, 180000, "Finance"],
    [49571, "Samantha Chen", 42, 220000, "Retail"],
    [50391, "Juan Rodriguez", 31, 160000, "Architecture"],
    [34556, "Lucas Hernandez", 37, 75000, "Education"],
    [64291, "Jessica Li", 25, 125000, "IT"],
    [74512, "Emma Davis", 47, 197000, "Finance"],
    [83191, "Sophia Perez", 34, 225000, "Transportation"],
    [91023, "Liam Kim", 29, 98000, "Retail"],
    [96435, "Ava Chen", 31, 175000, "Marketing"],
    [100571, "Noah Rodriguez", 28, 85000, "Architecture"],
    [101321, "Olivia Wilson", 44, 310000, "Telecom"],
    [104556, "William Brown", 38, 289000, "Finance"],
    [105491, "Emily Smith", 29, 193000, "Healthcare"],
    [107512, "Michael Perez", 53, 415000, "Transportation"]
]

incomes_per_field = {} # aquí colocarás los ingresos para cada campo

for client in clients:
    
	if incomes_per_field.get(client[-1]) == None:
		incomes_per_field[client[-1]] = []
		incomes_per_field[client[-1]].append(client[3])
	else:
		incomes_per_field[client[-1]].append(client[3])

print(incomes_per_field)
# Out:
# {'Healthcare': [150000, 193000], 'Telecom': [250000, 310000], 'IT': [210000, 125000], 'Transportation': [340000, 225000, 415000], 'Marketing': [120000, 175000], 'Finance': [180000, 197000, 289000], 'Retail': [220000, 98000], 'Architecture': [160000, 85000], 'Education': [75000]}

# %%
lst = [1, "aBc", 23, "c", 14.5]

for l in range(len(lst)):
    print(l)
# Out:
# 0
# 1
# 2
# 3
# 4
